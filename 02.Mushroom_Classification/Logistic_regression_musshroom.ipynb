# %% [markdown]
# <div style="background-color: #f0f8ff; padding: 20px; border-radius: 10px; border: 2px solid #b0c4de; text-align: center;">
#     <h1 style="color: #4682b4;">IMPORTING NECESSARY LIBRARIES</h1>
# </div>

# %%
import pandas as pd
import os
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error,r2_score,accuracy_score

# %%
os.chdir('D:\\data analyst\\kaggle datasets\\mushroom classification\\uci')

# %%
mdata_new=pd.read_csv('cleaned_musshroom_data')

# %% [markdown]
# <div style="background-color: #f0f8ff; padding: 20px; border-radius: 10px; border: 2px solid #b0c4de; text-align: center;">
#     <h1 style="color: #4682b4;">PREPARING DATA FOR MACHINE LEARNING </h1>
# </div>

# %%
mdata_new=pd.get_dummies(mdata_new,drop_first=True)

# %%
mdata_new.info
# Out:
# <bound method DataFrame.info of       cap-surface_g  cap-surface_s  cap-surface_y  cap-color_c  cap-color_e  \
# 0             False           True          False        False        False
# 1             False           True          False        False        False
# 2             False          False           True        False        False
# 3             False           True          False        False        False
# 4             False          False           True        False        False
# ...             ...            ...            ...          ...          ...
# 8118          False           True          False        False        False
# 8119          False           True          False        False        False
# 8120          False           True          False        False        False
# 8121          False          False           True        False        False
# 8122          False           True          False        False        False
#
# ...

# %%
# storing the column names of the data 
column_list=mdata_new.columns

# %%
print(column_list)
# Out:
# Index(['cap-surface_g', 'cap-surface_s', 'cap-surface_y', 'cap-color_c',
#        'cap-color_e', 'cap-color_g', 'cap-color_n', 'cap-color_p',
#        'cap-color_r', 'cap-color_u', 'cap-color_w', 'cap-color_y', 'bruises_t',
#        'gill-color_e', 'gill-color_g', 'gill-color_h', 'gill-color_k',
#        'gill-color_n', 'gill-color_o', 'gill-color_p', 'gill-color_r',
#        'gill-color_u', 'gill-color_w', 'gill-color_y', 'stalk-shape_t',
#        'habitat_g', 'habitat_l', 'habitat_m', 'habitat_p', 'habitat_u',
#        'habitat_w', 'target_p'],
#       dtype='object')

# %%
features=list(set(column_list)-set(mdata_new['target_p']))

# %%
print(features)
# Out:
# ['cap-color_e', 'gill-color_k', 'bruises_t', 'cap-surface_g', 'gill-color_o', 'cap-color_u', 'gill-color_w', 'gill-color_y', 'gill-color_h', 'habitat_g', 'habitat_u', 'gill-color_u', 'habitat_w', 'cap-surface_y', 'cap-color_p', 'stalk-shape_t', 'cap-color_r', 'gill-color_g', 'cap-surface_s', 'gill-color_n', 'habitat_p', 'habitat_l', 'gill-color_r', 'gill-color_e', 'cap-color_n', 'cap-color_g', 'habitat_m', 'target_p', 'cap-color_y', 'gill-color_p', 'cap-color_c', 'cap-color_w']

# %%
# storing the target variable in the y 
y=mdata_new['target_p'].values

# %%
x=mdata_new[features].values

# %%
##now splitting the data for training and testing
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
model=LogisticRegression()

# %%
model.fit(train_x,train_y)
# Out:
# LogisticRegression()

# %%
a=model.coef_ ##model coefficiant tells how much each variable is influencing the output of the model

# %%
print(a)
# Out:
# [[-0.02998782 -0.57246835 -0.77860589  0.03737663 -0.39271817 -0.15357896
#   -0.55958313 -0.37728199  0.01233238 -0.25440994  0.49124979 -0.60431038
#   -0.48033436  0.47099141  0.04266289 -0.21075027 -0.19215413 -0.08670377
#    0.45830919 -0.79881699  0.55879144  0.05327105  0.07864331 -0.29356219
#   -0.38380456 -0.2118975  -0.34920241 10.71924507  0.03454185 -0.31394043
#   -0.16171636 -0.25404458]]

# %%
prediction=model.predict(test_x)

# %%
result_check=confusion_matrix(test_y,prediction)

# %%
print(result_check)
# Out:
# [[796   0]
#  [  0 829]]

# %%
acc_score=accuracy_score(test_y,prediction)
print(acc_score)
# Out:
# 1.0

# %%
pred_df=pd.DataFrame({'Actual Value':test_y,'Predicted Value':LRprediction})
pred_df
# Out:
#       Actual Value  Predicted Value
# 0            False            False
# 1             True             True
# 2             True             True
# 3             True             True
# 4            False            False
# ...            ...              ...
# 1620          True             True
# 1621          True             True
# 1622          True             True
# 1623         False            False
# 1624         False            False
#
# [1625 rows x 2 columns]
